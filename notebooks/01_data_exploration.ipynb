# %%
# Data manipulation
import pandas as pd
import numpy as np

# %%
# Visualization 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Settings
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
plt.style.use('seaborn-v0_8-darkgrid')

# %matplotlib inline

print("✅ Libraries loaded successfully!")
# Out:
# ✅ Libraries loaded successfully!

# %%
# Load Lending Club data
df = pd.read_csv('../data/accepted_2007_to_2018Q4.csv')

print(f"✅ Data loaded successfully!")
print(f"\nDataset Shape: {df.shape}")
print(f"Rows: {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
# Out:
# C:\Users\zaina\AppData\Local\Temp\ipykernel_25200\2016853063.py:2: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/accepted_2007_to_2018Q4.csv')
# ✅ Data loaded successfully!
#
# Dataset Shape: (2260701, 151)
# Rows: 2,260,701
# Columns: 151

# %%
# Display first few rows
df.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85       829.90     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
# See all column names
print("Column Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB

# %%
# Check loan_status distribution
print("Loan Status Values:")
print(df['loan_status'].value_counts())
# Out:
# Loan Status Values:
# loan_status
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: count, dtype: int64

# %%
print("\n" + "="*60)

# %%
# Create binary target variable: 1 = default, 0=paid
default_statuses = ['Charged Off', 'Default',
                    'Late (31-120 days)', 'Late(16-30 days)',
                    'Does not meet the credit policy. Status:Charged Off']

df['default'] = df['loan_status'].apply(
    lambda x:1 if x in default_statuses else 0
)

print("\nDefault Distribution:") 
print(df['default'].value_counts())
print(f"\n✅ Overall Default Rate: {df['default'].mean():.2%}")
# Out:
# Default Distribution:
# default
# 0    1969874
# 1     290827
# Name: count, dtype: int64
#
# ✅ Overall Default Rate: 12.86%

# %%
# Check for missing value
missing = (df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
missing_df = pd.DataFrame({
    'Column': missing.index,
    'Missing_Percentage': missing.values
})

print("Top 15 columns with missing values:")
print(missing_df[missing_df['Missing_Percentage'] > 0].head(15))
# Out:
# Top 15 columns with missing values:
#                                         Column  Missing_Percentage
# 0                                    member_id          100.000000
# 1   orig_projected_additional_accrued_interest           99.617331
# 2                              hardship_status           99.517097
# 3                              hardship_amount           99.517097
# 4                 hardship_last_payment_amount           99.517097
# 5                              hardship_length           99.517097
# 6                      payment_plan_start_date           99.517097
# 7                              hardship_reason           99.517097
# 8                                deferral_term           99.517097
# 9               hardship_payoff_balance_amount           99.517097
# 10                           hardship_end_date           99.517097
# 11                         hardship_start_date           99.517097
# ...

# %%
import os
os.makedirs('../results', exist_ok=True)

# Fico Score Analysis
plt.figure(figsize=(14, 5))

plt.subplot(1,2,1)
plt.hist(df['fico_range_high'].dropna(), bins=50, edgecolor ='black', color ='steelblue')
plt.title('FICO Score Disttribution', fontsize=14, fontweight='bold')
plt.xlabel('FICO Score')
plt.ylabel('Number of Loans')
plt.grid(axis='y', alpha=0.3)

plt.subplot(1,2,2)
fico_bins = pd.cut(df['fico_range_high'], bins=[600,660,700,740,780, 850])
default_by_fico = df.groupby(fico_bins)['default'].mean()
default_by_fico.plot(kind ='bar', color='coral')
plt.title('Default Rate by FICO Score Range', fontsize=14, fontweight='bold')
plt.ylabel('Default Rate')
plt.xlabel('FICO Range')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('../results/default_by_fico.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nDefault Rate by FICO Score:")
print(default_by_fico)
# Out:
# C:\Users\zaina\AppData\Local\Temp\ipykernel_25200\1334143050.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   default_by_fico = df.groupby(fico_bins)['default'].mean()
# Default Rate by FICO Score:
# fico_range_high
# (600, 660]    0.308793
# (660, 700]    0.159571
# (700, 740]    0.099097
# (740, 780]    0.061165
# (780, 850]    0.041406
# Name: default, dtype: float64

# %%
# Default rate by loan grade
plt.figure(figsize=(10, 6))
grade_default=df.groupby('grade')['default'].mean().sort_index()
grade_default.plot(kind='bar', color='#2ecc71', edgecolor='black')
plt.title('Default Rate by Loan Grade(A=Best, G=Worst)', fontsize=14, fontweight='bold')
plt.xlabel('Loan Grade')
plt.ylabel('Default Rate')
plt.axhline(df['default'].mean(), color='red', linestyle='--', linewidth=2, label='Overall Default Rate')
plt.legend()
plt.xticks(rotation=0)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig('../results/default_by_grade.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nDefault Rate by Loan Grade:")
for grade, rate in grade_default.items():
    print(f"Grade{grade}: {rate:.2%}")
# Out:
# Default Rate by Loan Grade:
# GradeA: 3.59%
# GradeB: 8.66%
# GradeC: 14.36%
# GradeD: 20.35%
# GradeE: 28.28%
# GradeF: 36.42%
# GradeG: 40.01%

# %%
# Debt-to-Income ratio analysis
plt.figure(figsize=(10, 6))
dti_bins = pd.cut(df['dti'], bins=[0,10,20,30,40,100])
default_by_dti =df.groupby(dti_bins)['default'].mean()
default_by_dti.plot(kind='bar', color='#e74c3c', edgecolor='black')
plt.title('Default Rate by Debt-to-Income Ratio', fontsize=14, fontweight='bold')
plt.xlabel('DTI Ratio(%)')
plt.ylabel('Default Rate')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig('../results/default_by_dti.png', dpi=300, bbox_inches='tight')
plt.show()

print('\nDefault Rate by DTI:')
print(default_by_dti)
# Out:
# C:\Users\zaina\AppData\Local\Temp\ipykernel_25200\3285566558.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   default_by_dti =df.groupby(dti_bins)['default'].mean()
# Default Rate by DTI:
# dti
# (0, 10]      0.099238
# (10, 20]     0.117750
# (20, 30]     0.148032
# (30, 40]     0.173696
# (40, 100]    0.097372
# Name: default, dtype: float64
